# %%
import os
import sys
import cv2
import logging
import numpy as np
import csv
from scipy.interpolate import splprep, splev
from scipy.ndimage import gaussian_filter1d
import matplotlib.pyplot as plt

# ---------- 配置参数 ----------
from dataclasses import dataclass

@dataclass
class AnalysisConfig:
    pixel_size_um: float = 1.0
    min_contour_length: int = 50
    min_perimeter: float = 50.0
    smoothing_factor_ratio: float = 0.1
    max_reasonable_curvature_factor: float = 10.0
    endpoint_exclude_ratio: float = 0.02  # 2%
    circle_window_size: int = 7
    angle_window_size: int = 5

# ---------- 日志及辅助 ----------
def setup_logging(output_folder):
    log_file = os.path.join(output_folder, 'analysis.log')
    logging.basicConfig(
        level=logging.INFO,
        format='%(asctime)s - %(levelname)s - %(message)s',
        handlers=[
            logging.FileHandler(log_file, encoding='utf-8'),
            logging.StreamHandler()
        ]
    )

def create_output_folder(folder_path):
    if not os.path.exists(folder_path):
        os.makedirs(folder_path)

def validate_config(config):
    if config.pixel_size_um <= 0:
        raise ValueError("pixel_size_um必须大于0")
    if config.min_contour_length < 10:
        logging.warning("min_contour_length太小，可能影响曲率计算精度")
    if config.endpoint_exclude_ratio < 0 or config.endpoint_exclude_ratio > 0.4:
        raise ValueError("endpoint_exclude_ratio应在0到0.4之间")

# ---------- 图像预处理 ----------
class ImageProcessor:
    SUPPORTED_FORMATS = ('.png', '.jpg', '.jpeg', '.bmp', '.tiff', '.tif')

    def __init__(self, config):
        self.config = config
        self.check_dependencies()

    def check_dependencies(self):
        if not hasattr(cv2, 'ximgproc'):
            raise ImportError("cv2.ximgproc模块不可用。请安装opencv-contrib-python")

    def preprocess_image(self, image_path):
        try:
            img = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
            if img is None:
                raise ValueError(f"无法加载图像: {image_path}")

            h, w = img.shape
            max_size = 2048
            if max(h, w) > max_size:
                scale = max_size / max(h, w)
                img = cv2.resize(img, (int(w*scale), int(h*scale)), interpolation=cv2.INTER_AREA)
                logging.info(f"图像尺寸缩放至: {img.shape[1]}x{img.shape[0]}")

            # 高斯模糊降噪
            img = cv2.GaussianBlur(img, (3, 3), 0)

            # 自适应阈值，反转得到前景白色
            binary = cv2.adaptiveThreshold(img, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                           cv2.THRESH_BINARY_INV, 11, 2)

            kernel = np.ones((2, 2), np.uint8)
            binary = cv2.morphologyEx(binary, cv2.MORPH_CLOSE, kernel)
            binary = cv2.morphologyEx(binary, cv2.MORPH_OPEN, kernel)

            # 使用ximgproc thinning 细化骨架
            skeleton = cv2.ximgproc.thinning(binary)
            return skeleton

        except Exception as e:
            logging.error(f"图像预处理失败 ({image_path}): {e}")
            return None

# ---------- 轮廓分析 ----------
class ContourAnalyzer:
    def __init__(self, config):
        self.config = config

    def extract_contours(self, skeleton):
        contours, _ = cv2.findContours(skeleton, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_NONE)
        valid = []
        for cnt in contours:
            if len(cnt) >= self.config.min_contour_length:
                perimeter = cv2.arcLength(cnt, False)
                if perimeter > self.config.min_perimeter:
                    valid.append(cnt)
        return valid

    def resample_contour(self, points, num_points=None):
        if num_points is None:
            num_points = len(points)
        distances = np.sqrt(np.sum(np.diff(points, axis=0)**2, axis=1))
        cumdist = np.concatenate(([0], np.cumsum(distances)))
        if cumdist[-1] == 0:
            return points
        uniform_dist = np.linspace(0, cumdist[-1], num_points)
        x_interp = np.interp(uniform_dist, cumdist, points[:, 0])
        y_interp = np.interp(uniform_dist, cumdist, points[:, 1])
        return np.column_stack((x_interp, y_interp))

    def smooth_contour_spline(self, points, smoothing_factor=None):
        if len(points) < 4:
            return points
        if smoothing_factor is None:
            smoothing_factor = len(points) * self.config.smoothing_factor_ratio
        try:
            tck, u = splprep([points[:, 0], points[:, 1]], s=smoothing_factor, per=False, k=min(3, len(points)-1))
            u_fine = np.linspace(0, 1, len(points)*2)
            smooth_points = np.array(splev(u_fine, tck)).T
            return smooth_points
        except Exception as e:
            logging.warning(f"B样条平滑失败: {e}")
            return points

# ---------- 曲率计算 ----------
class CurvatureCalculator:
    def __init__(self, config):
        self.config = config

    def calculate_curvature_angle_based(self, points):
        n = len(points)
        curv = np.zeros(n)
        points_um = points * self.config.pixel_size_um
        exclude_count = max(2, int(n * self.config.endpoint_exclude_ratio))
        start = exclude_count
        end = n - exclude_count
        window = self.config.angle_window_size
        for i in range(start, end):
            prev_idx = max(0, i - window // 2)
            next_idx = min(n - 1, i + window // 2)
            if next_idx - prev_idx >= 2:
                v1 = points_um[i] - points_um[prev_idx]
                v2 = points_um[next_idx] - points_um[i]
                len1 = np.linalg.norm(v1)
                len2 = np.linalg.norm(v2)
                if len1 > 1e-10 and len2 > 1e-10:
                    cos_theta = np.dot(v1, v2) / (len1 * len2)
                    cos_theta = np.clip(cos_theta, -1, 1)
                    angle = np.arccos(cos_theta)
                    arc_length = (len1 + len2) / 2
                    if arc_length > 1e-10:
                        curv[i] = angle / arc_length
        # 曲率平滑
        curv = gaussian_filter1d(curv, sigma=1)
        return curv

# ---------- 曲率质量评估 ----------
class QualityAssessor:
    def __init__(self, config):
        self.config = config

    def assess_curvature_quality(self, curvatures, points):
        n = len(curvatures)
        if n < 10:
            return {'valid_ratio': 0, 'endpoint_effect': True, 'mean_curvature': 0,
                    'std_curvature': 0, 'valid_count': 0}

        valid_mask = curvatures > 0.001
        valid_ratio = np.sum(valid_mask) / n

        exclude_count = max(2, int(n * self.config.endpoint_exclude_ratio))
        front = curvatures[:exclude_count]
        back = curvatures[-exclude_count:]
        middle = curvatures[exclude_count:-exclude_count] if exclude_count < n//2 else curvatures[n//4:-n//4]

        endpoint_effect = False
        if len(middle) > 0 and np.mean(middle) > 0:
            front_mean = np.mean(front[front > 0.001]) if np.any(front > 0.001) else 0
            back_mean = np.mean(back[back > 0.001]) if np.any(back > 0.001) else 0
            middle_mean = np.mean(middle[middle > 0.001]) if np.any(middle > 0.001) else 0
            if middle_mean > 0:
                front_ratio = front_mean / middle_mean if front_mean > 0 else 0
                back_ratio = back_mean / middle_mean if back_mean > 0 else 0
                endpoint_effect = front_ratio > 2.0 or back_ratio > 2.0

        valid_curv = curvatures[valid_mask]
        mean_c = np.mean(valid_curv) if len(valid_curv) > 0 else 0
        std_c = np.std(valid_curv) if len(valid_curv) > 1 else 0

        return {'valid_ratio': valid_ratio, 'endpoint_effect': endpoint_effect,
                'mean_curvature': mean_c, 'std_curvature': std_c, 'valid_count': len(valid_curv)}

    def print_contour_stats(self, contour_id, points, angle_curv, angle_q):
        valid_angle = angle_curv[angle_curv > 0.001]
        print(f"  Contour {contour_id}: {len(points)} points")
        print(f"    Angle:  {np.mean(valid_angle):.6f} 1/μm (valid: {len(valid_angle)}/{len(points)}) {'⚠️' if angle_q['endpoint_effect'] else '✓'}")

# ---------- 可视化 ----------
class CurvatureVisualizer:
    def __init__(self, config):
        self.config = config

    def visualize_all_contours(self, all_contours_data, output_path):
        if not all_contours_data:
            return
        fig, axes = plt.subplots(1, 3, figsize=(15, 5))
        colors = plt.cm.tab10(np.linspace(0, 1, len(all_contours_data)))

        # 1. 原始轮廓
        ax = axes[0]
        for i, data in enumerate(all_contours_data):
            points = data['points']
            ax.plot(points[:, 0], points[:, 1], color=colors[i], linewidth=2, alpha=0.8, label=f'Contour {i+1}')
        ax.set_title('Original Contours')
        ax.set_xlabel('X (pixels)')
        ax.set_ylabel('Y (pixels)')
        ax.axis('equal')
        ax.grid(True, alpha=0.3)
        ax.legend(fontsize=8)

        # 2. 角度曲率散点图
        ax = axes[1]
        scatter = None
        for i, data in enumerate(all_contours_data):
            points = data['points']
            curvature = data['angle_curvature']
            valid_mask = curvature > 0.001
            if np.any(valid_mask):
                scatter = ax.scatter(points[valid_mask, 0], points[valid_mask, 1],
                                     c=curvature[valid_mask], cmap='jet', s=15, alpha=0.8)
        ax.set_title('Angle-based Curvature')
        ax.axis('equal')
        ax.grid(True, alpha=0.3)
        if scatter is not None:
            cbar = plt.colorbar(scatter, ax=ax)
            cbar.set_label('Curvature (1/μm)', rotation=270, labelpad=15)

        # 3. 曲率直方图
        ax = axes[2]
        all_angle = []
        for data in all_contours_data:
            valid = data['angle_curvature'][data['angle_curvature'] > 0.001]
            all_angle.extend(valid)
        if all_angle:
            ax.hist(all_angle, bins=30, color='green', alpha=0.7, edgecolor='black')
            ax.set_title(f'Angle Curvature\n(Mean: {np.mean(all_angle):.4f} ± {np.std(all_angle):.4f} 1/μm)')
        else:
            ax.set_title('Angle Curvature\n(No valid data)')
        ax.set_xlabel('Curvature (1/μm)')
        ax.set_ylabel('Frequency')
        ax.grid(True, alpha=0.3)

        plt.tight_layout()
        plt.savefig(output_path, dpi=300, bbox_inches='tight')
        plt.close()
        logging.info(f"Visualization saved to: {output_path}")

# ---------- 数据导出 ----------
class DataExporter:
    def __init__(self, config):
        self.config = config

    def save_csv_data(self, all_contours_data, output_path):
        header = ['contour_id', 'point_id', 'x_um', 'y_um', 'angle_curvature', 'angle_valid']
        try:
            with open(output_path, 'w', newline='', encoding='utf-8') as csvfile:
                writer = csv.writer(csvfile)
                writer.writerow(header)
                for contour_id, data in enumerate(all_contours_data):
                    points = data['points']
                    points_um = points * self.config.pixel_size_um
                    angle_curvature = data['angle_curvature']
                    for point_id, (x, y, ac) in enumerate(zip(points_um[:, 0], points_um[:, 1], angle_curvature)):
                        angle_valid = ac > 0.001
                        writer.writerow([contour_id, point_id, x, y, ac, angle_valid])
            logging.info(f"CSV data saved to: {output_path}")
        except Exception as e:
            logging.error(f"Failed to save CSV data: {e}")

    def save_summary_report(self, all_results, output_path):
        try:
            with open(output_path, 'w', encoding='utf-8') as f:
                f.write("# 曲率分析汇总报告\n\n")
                f.write(f"## 分析配置\n")
                f.write(f"- 像素尺寸: {self.config.pixel_size_um} μm/pixel\n")
                f.write(f"- 最小轮廓长度: {self.config.min_contour_length}\n")
                f.write(f"- 端点排除比例: {self.config.endpoint_exclude_ratio}\n")
                f.write(f"- 角度窗口大小: {self.config.angle_window_size}\n\n")
                total_contours = 0
                total_valid_points = 0
                all_angle_means = []
                for image_name, data_list in all_results.items():
                    f.write(f"## {image_name}\n")
                    total_contours += len(data_list)
                    for i, data in enumerate(data_list):
                        quality = data['quality_metrics']
                        f.write(f"### 轮廓 {i+1}\n")
                        f.write(f"- 点数: {len(data['points'])}\n")
                        f.write(f"- 角度曲率: 均值={quality['angle']['mean_curvature']:.6f}, 有效点={quality['angle']['valid_count']}\n\n")
                        total_valid_points += quality['angle']['valid_count']
                        if quality['angle']['mean_curvature'] > 0:
                            all_angle_means.append(quality['angle']['mean_curvature'])
                    f.write("\n")
                f.write(f"## 总体统计\n")
                f.write(f"- 处理图像数: {len(all_results)}\n")
                f.write(f"- 总轮廓数: {total_contours}\n")
                f.write(f"- 总有效点数: {total_valid_points}\n")
                if all_angle_means:
                    f.write(f"- 角度方法平均曲率: {np.mean(all_angle_means):.6f} ± {np.std(all_angle_means):.6f} 1/μm\n")
            logging.info(f"Summary report saved to: {output_path}")
        except Exception as e:
            logging.error(f"Failed to save summary report: {e}")

# ---------- 主控制类 ----------
class CurvatureAnalyzer:
    SUPPORTED_FORMATS = ('.png', '.jpg', '.jpeg', '.bmp', '.tiff', '.tif')

    def __init__(self, input_folder, output_folder=None, config=None):
        self.input_folder = input_folder
        if output_folder is None:
            output_folder = os.path.join(input_folder, "curvature_results")
        self.output_folder = output_folder
        self.config = config or AnalysisConfig()

        self.image_processor = ImageProcessor(self.config)
        self.contour_analyzer = ContourAnalyzer(self.config)
        self.curvature_calculator = CurvatureCalculator(self.config)
        self.quality_assessor = QualityAssessor(self.config)
        self.visualizer = CurvatureVisualizer(self.config)
        self.data_exporter = DataExporter(self.config)

        create_output_folder(self.output_folder)
        setup_logging(self.output_folder)
        validate_config(self.config)

    def process_single_image(self, image_path):
        print(f"Processing: {os.path.basename(image_path)}")
        logging.info(f"Processing image: {image_path}")

        skeleton = self.image_processor.preprocess_image(image_path)
        if skeleton is None:
            print(f"Failed to load or preprocess image: {os.path.basename(image_path)}")
            return []

        contours = self.contour_analyzer.extract_contours(skeleton)
        if not contours:
            print(f"No valid contours found in {os.path.basename(image_path)}")
            return []

        all_contours_data = []
        for i, contour in enumerate(contours):
            points = contour.reshape(-1, 2).astype(np.float64)
            if len(points) < 15:
                continue

            resampled = self.contour_analyzer.resample_contour(points, len(points))
            smooth = self.contour_analyzer.smooth_contour_spline(resampled)

            angle_curv = self.curvature_calculator.calculate_curvature_angle_based(smooth)
            angle_quality = self.quality_assessor.assess_curvature_quality(angle_curv, smooth)

            contour_data = {
                'points': smooth,
                'angle_curvature': angle_curv,
                'quality_metrics': {'angle': angle_quality}
            }
            all_contours_data.append(contour_data)

            self.quality_assessor.print_contour_stats(i, smooth, angle_curv, angle_quality)

        return all_contours_data

    def process_all_images(self):
        image_files = [os.path.join(self.input_folder, f) for f in os.listdir(self.input_folder)
                       if f.lower().endswith(self.SUPPORTED_FORMATS)]

        if not image_files:
            print("No image files found in input folder.")
            logging.warning("No image files found in input folder.")
            return

        print(f"Found {len(image_files)} image files.")
        print(f"Pixel size: {self.config.pixel_size_um} μm/pixel")
        print(f"Endpoint exclude ratio: {self.config.endpoint_exclude_ratio}")

        logging.info(f"Starting batch processing ({len(image_files)} images).")
        logging.info(f"Config: {self.config}")

        all_results = {}

        for img_path in image_files:
            try:
                contours_data = self.process_single_image(img_path)
                if contours_data:
                    base_name = os.path.splitext(os.path.basename(img_path))[0]
                    viz_path = os.path.join(self.output_folder, f"{base_name}_curvature_analysis.png")
                    csv_path = os.path.join(self.output_folder, f"{base_name}_curvature_data.csv")

                    self.visualizer.visualize_all_contours(contours_data, viz_path)
                    self.data_exporter.save_csv_data(contours_data, csv_path)

                    all_results[base_name] = contours_data
                else:
                    logging.warning(f"No valid contours in {img_path}")
            except Exception as e:
                logging.error(f"Error processing {img_path}: {e}", exc_info=True)
                print(f"Error processing {img_path}: {e}")

        if all_results:
            summary_path = os.path.join(self.output_folder, "summary_report.md")
            self.data_exporter.save_summary_report(all_results, summary_path)

        print(f"\nProcessing completed. Results saved in: {self.output_folder}")
        logging.info("Batch processing finished.")

# ---------- 主程序入口 ----------
def main():
    input_folder = r"C:\Users\chenb\Desktop\input_images"
    # 输出目录放在input_images目录内
    output_folder = os.path.join(input_folder, "curvature_results")

    config = AnalysisConfig(
        pixel_size_um=1.0,
        min_contour_length=50,
        min_perimeter=50.0,
        smoothing_factor_ratio=0.1,
        max_reasonable_curvature_factor=10.0,
        endpoint_exclude_ratio=0.02,
        circle_window_size=7,
        angle_window_size=5
    )

    try:
        analyzer = CurvatureAnalyzer(input_folder, output_folder, config)
        analyzer.process_all_images()
    except Exception as e:
        print(f"程序运行出错: {e}")
        logging.error(f"Fatal error: {e}", exc_info=True)
        sys.exit(1)

if __name__ == "__main__":
    main()
# Out:
# 2025-11-22 00:03:43,144 - INFO - Starting batch processing (1 images).
# 2025-11-22 00:03:43,146 - INFO - Config: AnalysisConfig(pixel_size_um=1.0, min_contour_length=50, min_perimeter=50.0, smoothing_factor_ratio=0.1, max_reasonable_curvature_factor=10.0, endpoint_exclude_ratio=0.02, circle_window_size=7, angle_window_size=5)
# 2025-11-22 00:03:43,148 - INFO - Processing image: C:\Users\chenb\Desktop\input_images\2108854-2-masson-4_02_Hematoxylin_Channel (3)_processed.png
# Found 1 image files.
# Pixel size: 1.0 μm/pixel
# Endpoint exclude ratio: 0.02
# Processing: 2108854-2-masson-4_02_Hematoxylin_Channel (3)_processed.png
#   Contour 0: 176 points
#     Angle:  0.255761 1/μm (valid: 173/176) ✓
#   Contour 1: 120 points
#     Angle:  0.269034 1/μm (valid: 120/120) ✓
#   Contour 2: 228 points
#     Angle:  0.260109 1/μm (valid: 224/228) ✓
#   Contour 3: 102 points
#     Angle:  0.311517 1/μm (valid: 99/102) ✓
#   Contour 4: 156 points
#     Angle:  0.254960 1/μm (valid: 154/156) ✓
#   Contour 5: 132 points
#     Angle:  0.154667 1/μm (valid: 132/132) ✓
#   Contour 6: 164 points
#     Angle:  0.253897 1/μm (valid: 162/164) ✓
#   Contour 7: 156 points
#     Angle:  0.181326 1/μm (valid: 153/156) ✓
#   Contour 8: 128 points
#     Angle:  0.359844 1/μm (valid: 128/128) ✓
#   Contour 9: 112 points
#     Angle:  0.261182 1/μm (valid: 112/112) ✓
#   Contour 10: 204 points
#     Angle:  0.222845 1/μm (valid: 200/204) ✓
#   Contour 11: 762 points
#     Angle:  0.103434 1/μm (valid: 673/762) ✓
#   Contour 12: 154 points
#     Angle:  0.244864 1/μm (valid: 152/154) ✓
#   Contour 13: 260 points
#     Angle:  0.249080 1/μm (valid: 254/260) ✓
#   Contour 14: 192 points
#     Angle:  0.243637 1/μm (valid: 190/192) ✓
#   Contour 15: 448 points
#     Angle:  0.121259 1/μm (valid: 409/448) ✓
#   Contour 16: 128 points
#     Angle:  0.135921 1/μm (valid: 119/128) ✓
#   Contour 17: 126 points
#     Angle:  0.184860 1/μm (valid: 126/126) ✓
#   Contour 18: 636 points
#     Angle:  0.112067 1/μm (valid: 614/636) ✓
#   Contour 19: 298 points
#     Angle:  0.134620 1/μm (valid: 286/298) ✓
#   Contour 20: 140 points
#     Angle:  0.267980 1/μm (valid: 140/140) ✓
#   Contour 21: 286 points
#     Angle:  0.178761 1/μm (valid: 273/286) ✓
#   Contour 22: 294 points
#     Angle:  0.218128 1/μm (valid: 282/294) ✓
#   Contour 23: 296 points
#     Angle:  0.203316 1/μm (valid: 290/296) ✓
#   Contour 24: 220 points
#     Angle:  0.146041 1/μm (valid: 215/220) ✓
#   Contour 25: 220 points
#     Angle:  0.151467 1/μm (valid: 215/220) ✓
#   Contour 26: 378 points
#     Angle:  0.085254 1/μm (valid: 365/378) ✓
#   Contour 27: 244 points
#     Angle:  0.133202 1/μm (valid: 240/244) ✓
#   Contour 28: 646 points
#     Angle:  0.088400 1/μm (valid: 623/646) ✓
#   Contour 29: 288 points
#     Angle:  0.156904 1/μm (valid: 280/288) ✓
#   Contour 30: 364 points
#     Angle:  0.073177 1/μm (valid: 354/364) ✓
#   Contour 31: 210 points
#     Angle:  0.160085 1/μm (valid: 206/210) ✓
#   Contour 32: 112 points
#     Angle:  0.278737 1/μm (valid: 111/112) ✓
#   Contour 33: 168 points
#     Angle:  0.127799 1/μm (valid: 129/168) ✓
#   Contour 34: 100 points
#     Angle:  0.263654 1/μm (valid: 99/100) ✓
#   Contour 35: 132 points
#     Angle:  0.314039 1/μm (valid: 132/132) ✓
#   Contour 36: 346 points
#     Angle:  0.178773 1/μm (valid: 330/346) ✓
#   Contour 37: 256 points
#     Angle:  0.130409 1/μm (valid: 249/256) ✓
#   Contour 38: 168 points
#     Angle:  0.184364 1/μm (valid: 166/168) ✓
#   Contour 39: 214 points
#     Angle:  0.164474 1/μm (valid: 196/214) ✓
#   Contour 40: 762 points
#     Angle:  0.124726 1/μm (valid: 736/762) ✓
#   Contour 41: 184 points
#     Angle:  0.184759 1/μm (valid: 182/184) ✓
#   Contour 42: 164 points
#     Angle:  0.124486 1/μm (valid: 139/164) ✓
#   Contour 43: 208 points
#     Angle:  0.164134 1/μm (valid: 203/208) ✓
#   Contour 44: 390 points
#     Angle:  0.094163 1/μm (valid: 380/390) ✓
#   Contour 45: 164 points
#     Angle:  0.123288 1/μm (valid: 156/164) ✓
#   Contour 46: 128 points
#     Angle:  0.234364 1/μm (valid: 128/128) ✓
#   Contour 47: 144 points
#     Angle:  0.270074 1/μm (valid: 141/144) ✓
#   Contour 48: 638 points
#     Angle:  0.082748 1/μm (valid: 615/638) ✓
#   Contour 49: 288 points
#     Angle:  0.120410 1/μm (valid: 270/288) ✓
#   Contour 50: 416 points
#     Angle:  0.101717 1/μm (valid: 402/416) ✓
#   Contour 51: 236 points
#     Angle:  0.193321 1/μm (valid: 227/236) ✓
#   Contour 52: 216 points
#     Angle:  0.157860 1/μm (valid: 202/216) ✓
#   Contour 53: 100 points
#     Angle:  0.155788 1/μm (valid: 100/100) ✓
#   Contour 54: 136 points
#     Angle:  0.207995 1/μm (valid: 135/136) ✓
#   Contour 55: 384 points
#     Angle:  0.112069 1/μm (valid: 348/384) ✓
#   Contour 56: 104 points
#     Angle:  0.352470 1/μm (valid: 102/104) ✓
#   Contour 57: 798 points
#     Angle:  0.071064 1/μm (valid: 759/798) ✓
#   Contour 58: 260 points
#     Angle:  0.160250 1/μm (valid: 227/260) ✓
#   Contour 59: 188 points
#     Angle:  0.100326 1/μm (valid: 186/188) ✓
#   Contour 60: 188 points
#     Angle:  0.155080 1/μm (valid: 185/188) ✓
#   Contour 61: 140 points
#     Angle:  0.121341 1/μm (valid: 139/140) ✓
#   Contour 62: 100 points
#     Angle:  0.353603 1/μm (valid: 93/100) ✓
#   Contour 63: 214 points
#     Angle:  0.140731 1/μm (valid: 206/214) ✓
#   Contour 64: 878 points
#     Angle:  0.069874 1/μm (valid: 826/878) ✓
#   Contour 65: 176 points
#     Angle:  0.187969 1/μm (valid: 173/176) ✓
#   Contour 66: 386 points
#     Angle:  0.102061 1/μm (valid: 376/386) ✓
#   Contour 67: 524 points
#     Angle:  0.122491 1/μm (valid: 507/524) ✓
#   Contour 68: 140 points
#     Angle:  0.105215 1/μm (valid: 139/140) ✓
#   Contour 69: 108 points
#     Angle:  0.296226 1/μm (valid: 108/108) ✓
#   Contour 70: 190 points
#     Angle:  0.180264 1/μm (valid: 188/190) ✓
#   Contour 71: 112 points
#     Angle:  0.359879 1/μm (valid: 100/112) ✓
#   Contour 72: 194 points
#     Angle:  0.195736 1/μm (valid: 192/194) ✓
#   Contour 73: 890 points
#     Angle:  0.056858 1/μm (valid: 825/890) ✓
#   Contour 74: 592 points
#     Angle:  0.082741 1/μm (valid: 528/592) ✓
#   Contour 75: 388 points
#     Angle:  0.164593 1/μm (valid: 378/388) ✓
#   Contour 76: 272 points
#     Angle:  0.144590 1/μm (valid: 264/272) ✓
#   Contour 77: 132 points
#     Angle:  0.214001 1/μm (valid: 125/132) ✓
#   Contour 78: 132 points
#     Angle:  0.438170 1/μm (valid: 108/132) ✓
#   Contour 79: 112 points
#     Angle:  0.331285 1/μm (valid: 112/112) ✓
#   Contour 80: 164 points
#     Angle:  0.195000 1/μm (valid: 162/164) ✓
#   Contour 81: 782 points
#     Angle:  0.058578 1/μm (valid: 712/782) ✓
#   Contour 82: 208 points
#     Angle:  0.267747 1/μm (valid: 204/208) ✓
#   Contour 83: 152 points
#     Angle:  0.198777 1/μm (valid: 150/152) ✓
#   Contour 84: 310 points
#     Angle:  0.118498 1/μm (valid: 301/310) ✓
#   Contour 85: 348 points
#     Angle:  0.214748 1/μm (valid: 325/348) ✓
#   Contour 86: 808 points
#     Angle:  0.069028 1/μm (valid: 731/808) ✓
#   Contour 87: 538 points
#     Angle:  0.149359 1/μm (valid: 519/538) ✓
#   Contour 88: 412 points
#     Angle:  0.096754 1/μm (valid: 397/412) ✓
#   Contour 89: 288 points
#     Angle:  0.130793 1/μm (valid: 265/288) ✓
#   Contour 90: 372 points
#     Angle:  0.109381 1/μm (valid: 359/372) ✓
#   Contour 91: 1252 points
#     Angle:  0.094154 1/μm (valid: 1169/1252) ✓
#   Contour 92: 374 points
#     Angle:  0.159433 1/μm (valid: 362/374) ✓
#   Contour 93: 160 points
#     Angle:  0.186173 1/μm (valid: 158/160) ✓
#   Contour 94: 128 points
#     Angle:  0.242340 1/μm (valid: 126/128) ✓
#   Contour 95: 290 points
#     Angle:  0.120355 1/μm (valid: 283/290) ✓
#   Contour 96: 174 points
#     Angle:  0.197865 1/μm (valid: 171/174) ✓
#   Contour 97: 484 points
#     Angle:  0.116959 1/μm (valid: 469/484) ✓
#   Contour 98: 166 points
#     Angle:  0.194912 1/μm (valid: 159/166) ✓
#   Contour 99: 148 points
#     Angle:  0.235368 1/μm (valid: 143/148) ✓
#   Contour 100: 260 points
#     Angle:  0.089896 1/μm (valid: 252/260) ✓
#   Contour 101: 232 points
#     Angle:  0.157678 1/μm (valid: 222/232) ✓
#   Contour 102: 160 points
#     Angle:  0.242339 1/μm (valid: 144/160) ✓
#   Contour 103: 130 points
#     Angle:  0.229711 1/μm (valid: 130/130) ✓
#   Contour 104: 100 points
#     Angle:  0.307114 1/μm (valid: 93/100) ✓
#   Contour 105: 156 points
#     Angle:  0.200714 1/μm (valid: 152/156) ✓
#   Contour 106: 156 points
#     Angle:  0.264742 1/μm (valid: 154/156) ✓
#   Contour 107: 452 points
#     Angle:  0.107184 1/μm (valid: 437/452) ✓
#   Contour 108: 250 points
#     Angle:  0.269053 1/μm (valid: 244/250) ✓
#   Contour 109: 816 points
#     Angle:  0.120073 1/μm (valid: 762/816) ✓
#   Contour 110: 172 points
#     Angle:  0.194876 1/μm (valid: 167/172) ✓
#   Contour 111: 376 points
#     Angle:  0.103313 1/μm (valid: 350/376) ✓
#   Contour 112: 736 points
#     Angle:  0.127181 1/μm (valid: 702/736) ✓
#   Contour 113: 174 points
#     Angle:  0.199793 1/μm (valid: 172/174) ✓
#   Contour 114: 104 points
#     Angle:  0.280340 1/μm (valid: 104/104) ✓
#   Contour 115: 132 points
#     Angle:  0.253774 1/μm (valid: 132/132) ✓
#   Contour 116: 176 points
#     Angle:  0.220299 1/μm (valid: 162/176) ✓
#   Contour 117: 148 points
#     Angle:  0.130930 1/μm (valid: 148/148) ✓
#   Contour 118: 144 points
#     Angle:  0.278955 1/μm (valid: 143/144) ✓
#   Contour 119: 268 points
#     Angle:  0.185136 1/μm (valid: 261/268) ✓
#   Contour 120: 234 points
#     Angle:  0.153402 1/μm (valid: 225/234) ✓
#   Contour 121: 136 points
#     Angle:  0.256789 1/μm (valid: 136/136) ✓
#   Contour 122: 726 points
#     Angle:  0.119076 1/μm (valid: 702/726) ✓
#   Contour 123: 260 points
#     Angle:  0.146143 1/μm (valid: 243/260) ✓
#   Contour 124: 472 points
#     Angle:  0.115123 1/μm (valid: 449/472) ✓
#   Contour 125: 436 points
#     Angle:  0.122519 1/μm (valid: 421/436) ⚠️
#   Contour 126: 1000 points
#     Angle:  0.121103 1/μm (valid: 932/1000) ✓
#   Contour 127: 380 points
#     Angle:  0.106830 1/μm (valid: 362/380) ✓
#   Contour 128: 108 points
#     Angle:  0.696418 1/μm (valid: 76/108) ✓
#   Contour 129: 128 points
#     Angle:  0.212255 1/μm (valid: 128/128) ✓
#   Contour 130: 394 points
#     Angle:  0.112501 1/μm (valid: 370/394) ✓
#   Contour 131: 216 points
#     Angle:  0.158048 1/μm (valid: 205/216) ✓
#   Contour 132: 152 points
#     Angle:  0.368058 1/μm (valid: 149/152) ✓
#   Contour 133: 1096 points
#     Angle:  0.065785 1/μm (valid: 1048/1096) ✓
#   Contour 134: 106 points
#     Angle:  0.307004 1/μm (valid: 106/106) ✓
#   Contour 135: 630 points
#     Angle:  0.114367 1/μm (valid: 607/630) ✓
#   Contour 136: 204 points
#     Angle:  0.305300 1/μm (valid: 199/204) ✓
#   Contour 137: 124 points
#     Angle:  0.269643 1/μm (valid: 123/124) ✓
#   Contour 138: 114 points
#     Angle:  0.467465 1/μm (valid: 114/114) ✓
#   Contour 139: 272 points
#     Angle:  0.138351 1/μm (valid: 266/272) ✓
#   Contour 140: 236 points
#     Angle:  0.143613 1/μm (valid: 232/236) ✓
#   Contour 141: 174 points
#     Angle:  0.228676 1/μm (valid: 171/174) ✓
#   Contour 142: 108 points
#     Angle:  0.245647 1/μm (valid: 108/108) ✓
#   Contour 143: 252 points
#     Angle:  0.150217 1/μm (valid: 238/252) ✓
#   Contour 144: 120 points
#     Angle:  0.214309 1/μm (valid: 120/120) ✓
#   Contour 145: 104 points
#     Angle:  0.181440 1/μm (valid: 102/104) ✓
#   Contour 146: 104 points
#     Angle:  0.320490 1/μm (valid: 104/104) ✓
#   Contour 147: 280 points
#     Angle:  0.088789 1/μm (valid: 268/280) ✓
#   Contour 148: 264 points
#     Angle:  0.133256 1/μm (valid: 256/264) ✓
#   Contour 149: 384 points
#     Angle:  0.197077 1/μm (valid: 374/384) ✓
#   Contour 150: 358 points
#     Angle:  0.158375 1/μm (valid: 337/358) ✓
#   Contour 151: 132 points
#     Angle:  0.283181 1/μm (valid: 127/132) ✓
#   Contour 152: 278 points
#     Angle:  0.124865 1/μm (valid: 271/278) ✓
#   Contour 153: 224 points
#     Angle:  0.163833 1/μm (valid: 210/224) ✓
#   Contour 154: 118 points
#     Angle:  0.203440 1/μm (valid: 118/118) ✓
#   Contour 155: 128 points
#     Angle:  0.235014 1/μm (valid: 125/128) ✓
#   Contour 156: 108 points
#     Angle:  0.301885 1/μm (valid: 108/108) ✓
#   Contour 157: 158 points
#     Angle:  0.205041 1/μm (valid: 156/158) ✓
#   Contour 158: 192 points
#     Angle:  0.168342 1/μm (valid: 190/192) ✓
#   Contour 159: 1964 points
#     Angle:  0.068566 1/μm (valid: 1839/1964) ✓
#   Contour 160: 152 points
#     Angle:  0.288022 1/μm (valid: 148/152) ✓
#   Contour 161: 124 points
#     Angle:  0.292008 1/μm (valid: 116/124) ✓
#   Contour 162: 394 points
#     Angle:  0.113200 1/μm (valid: 330/394) ✓
#   Contour 163: 706 points
#     Angle:  0.122437 1/μm (valid: 679/706) ✓
#   Contour 164: 318 points
#     Angle:  0.135084 1/μm (valid: 300/318) ✓
#   Contour 165: 462 points
#     Angle:  0.127202 1/μm (valid: 446/462) ✓
#   Contour 166: 168 points
#     Angle:  5.100662 1/μm (valid: 10/168) ✓
#   Contour 167: 144 points
#     Angle:  0.335977 1/μm (valid: 144/144) ✓
#   Contour 168: 180 points
#     Angle:  0.189417 1/μm (valid: 178/180) ✓
#   Contour 169: 352 points
#     Angle:  0.141470 1/μm (valid: 338/352) ✓
#   Contour 170: 404 points
#     Angle:  0.110188 1/μm (valid: 391/404) ✓
#   Contour 171: 164 points
#     Angle:  0.241424 1/μm (valid: 152/164) ✓
#   Contour 172: 312 points
#     Angle:  0.092140 1/μm (valid: 304/312) ✓
#   Contour 173: 306 points
#     Angle:  0.128432 1/μm (valid: 293/306) ✓
#   Contour 174: 128 points
#     Angle:  0.231164 1/μm (valid: 128/128) ✓
#   Contour 175: 372 points
#     Angle:  0.201376 1/μm (valid: 353/372) ✓
#   Contour 176: 216 points
#     Angle:  0.149183 1/μm (valid: 208/216) ✓
#   Contour 177: 326 points
#     Angle:  0.206518 1/μm (valid: 317/326) ✓
#   Contour 178: 566 points
#     Angle:  0.104258 1/μm (valid: 529/566) ✓
#   Contour 179: 174 points
#     Angle:  0.135967 1/μm (valid: 172/174) ✓
#   Contour 180: 286 points
#     Angle:  0.139999 1/μm (valid: 270/286) ✓
#   Contour 181: 132 points
#     Angle:  0.217114 1/μm (valid: 131/132) ✓
#   Contour 182: 148 points
#     Angle:  0.221997 1/μm (valid: 148/148) ✓
#   Contour 183: 216 points
#     Angle:  0.260471 1/μm (valid: 213/216) ✓
#   Contour 184: 554 points
#     Angle:  0.085556 1/μm (valid: 536/554) ✓
#   Contour 185: 320 points
#     Angle:  0.114742 1/μm (valid: 303/320) ✓
#   Contour 186: 128 points
#     Angle:  0.236289 1/μm (valid: 126/128) ✓
#   Contour 187: 174 points
#     Angle:  0.288422 1/μm (valid: 172/174) ✓
#   Contour 188: 648 points
#     Angle:  0.112463 1/μm (valid: 610/648) ✓
#   Contour 189: 140 points
#     Angle:  0.152393 1/μm (valid: 138/140) ✓
#   Contour 190: 128 points
#     Angle:  0.199997 1/μm (valid: 128/128) ✓
#   Contour 191: 132 points
#     Angle:  0.199006 1/μm (valid: 130/132) ✓
#   Contour 192: 126 points
#     Angle:  0.302202 1/μm (valid: 124/126) ✓
#   Contour 193: 136 points
#     Angle:  0.340185 1/μm (valid: 136/136) ✓
#   Contour 194: 256 points
#     Angle:  0.210288 1/μm (valid: 248/256) ✓
#   Contour 195: 296 points
#     Angle:  0.163045 1/μm (valid: 285/296) ✓
#   Contour 196: 442 points
#     Angle:  0.085260 1/μm (valid: 426/442) ✓
#   Contour 197: 478 points
#     Angle:  0.095682 1/μm (valid: 449/478) ✓
#   Contour 198: 266 points
#     Angle:  0.156043 1/μm (valid: 254/266) ✓
#   Contour 199: 750 points
#     Angle:  0.118783 1/μm (valid: 720/750) ✓
#   Contour 200: 276 points
#     Angle:  0.133589 1/μm (valid: 263/276) ✓
#   Contour 201: 1240 points
#     Angle:  0.079779 1/μm (valid: 1153/1240) ✓
#   Contour 202: 832 points
#     Angle:  0.122582 1/μm (valid: 780/832) ✓
#   Contour 203: 414 points
#     Angle:  0.102823 1/μm (valid: 394/414) ✓
#   Contour 204: 324 points
#     Angle:  0.074620 1/μm (valid: 312/324) ✓
#   Contour 205: 218 points
#     Angle:  0.276191 1/μm (valid: 213/218) ✓
#   Contour 206: 196 points
#     Angle:  0.203355 1/μm (valid: 195/196) ⚠️
#   Contour 207: 132 points
#     Angle:  0.249922 1/μm (valid: 132/132) ✓
#   Contour 208: 268 points
#     Angle:  5.763903 1/μm (valid: 10/268) ✓
#   Contour 209: 168 points
#     Angle:  0.200216 1/μm (valid: 160/168) ✓
#   Contour 210: 416 points
#     Angle:  0.145037 1/μm (valid: 395/416) ✓
#   Contour 211: 128 points
#     Angle:  0.251031 1/μm (valid: 128/128) ✓
#   Contour 212: 236 points
#     Angle:  0.146285 1/μm (valid: 232/236) ✓
#   Contour 213: 152 points
#     Angle:  0.266127 1/μm (valid: 150/152) ✓
#   Contour 214: 120 points
#     Angle:  0.226730 1/μm (valid: 120/120) ✓
#   Contour 215: 1198 points
#     Angle:  0.099579 1/μm (valid: 1147/1198) ✓
#   Contour 216: 334 points
#     Angle:  0.119962 1/μm (valid: 326/334) ✓
#   Contour 217: 308 points
#     Angle:  0.105606 1/μm (valid: 300/308) ✓
#   Contour 218: 412 points
#     Angle:  0.122866 1/μm (valid: 398/412) ✓
#   Contour 219: 332 points
#     Angle:  0.196281 1/μm (valid: 315/332) ✓
#   Contour 220: 760 points
#     Angle:  0.067544 1/μm (valid: 687/760) ✓
#   Contour 221: 336 points
#     Angle:  0.104398 1/μm (valid: 320/336) ✓
#   Contour 222: 568 points
#     Angle:  0.063782 1/μm (valid: 537/568) ⚠️
#   Contour 223: 108 points
#     Angle:  0.286996 1/μm (valid: 108/108) ✓
#   Contour 224: 224 points
#     Angle:  0.205040 1/μm (valid: 220/224) ✓
#   Contour 225: 616 points
#     Angle:  0.096034 1/μm (valid: 592/616) ✓
#   Contour 226: 428 points
#     Angle:  0.120412 1/μm (valid: 409/428) ✓
#   Contour 227: 140 points
#     Angle:  0.217208 1/μm (valid: 140/140) ✓
#   Contour 228: 1036 points
#     Angle:  0.063555 1/μm (valid: 981/1036) ✓
#   Contour 229: 268 points
#     Angle:  0.160945 1/μm (valid: 262/268) ✓
#   Contour 230: 196 points
#     Angle:  0.178354 1/μm (valid: 193/196) ✓
#   Contour 231: 484 points
#     Angle:  0.150148 1/μm (valid: 436/484) ✓
#   Contour 232: 436 points
#     Angle:  0.101652 1/μm (valid: 417/436) ⚠️
#   Contour 233: 100 points
#     Angle:  0.411708 1/μm (valid: 100/100) ✓
#   Contour 234: 2368 points
#     Angle:  0.103002 1/μm (valid: 2251/2368) ✓
#   Contour 235: 152 points
#     Angle:  0.279867 1/μm (valid: 150/152) ✓
#   Contour 236: 420 points
#     Angle:  0.094251 1/μm (valid: 407/420) ✓
#   Contour 237: 182 points
#     Angle:  0.184865 1/μm (valid: 177/182) ✓
#   Contour 238: 396 points
#     Angle:  0.132101 1/μm (valid: 385/396) ✓
#   Contour 239: 642 points
#     Angle:  0.075751 1/μm (valid: 614/642) ✓
#   Contour 240: 242 points
#     Angle:  0.167224 1/μm (valid: 238/242) ✓
#   Contour 241: 172 points
#     Angle:  0.231541 1/μm (valid: 170/172) ✓
#   Contour 242: 172 points
#     Angle:  0.199889 1/μm (valid: 170/172) ✓
#   Contour 243: 140 points
#     Angle:  0.160973 1/μm (valid: 136/140) ✓
#   Contour 244: 216 points
#     Angle:  0.175255 1/μm (valid: 209/216) ✓
#   Contour 245: 652 points
#     Angle:  0.051777 1/μm (valid: 619/652) ✓
#   Contour 246: 176 points
#     Angle:  0.213640 1/μm (valid: 166/176) ✓
#   Contour 247: 700 points
#     Angle:  0.119878 1/μm (valid: 642/700) ✓
#   Contour 248: 608 points
#     Angle:  0.075830 1/μm (valid: 583/608) ✓
#   Contour 249: 216 points
#     Angle:  0.136585 1/μm (valid: 204/216) ✓
#   Contour 250: 132 points
#     Angle:  0.202628 1/μm (valid: 132/132) ✓
#   Contour 251: 140 points
#     Angle:  0.212620 1/μm (valid: 138/140) ✓
#   Contour 252: 382 points
#     Angle:  0.232677 1/μm (valid: 372/382) ✓
#   Contour 253: 256 points
#     Angle:  0.118597 1/μm (valid: 243/256) ⚠️
#   Contour 254: 220 points
#     Angle:  0.132819 1/μm (valid: 210/220) ✓
#   Contour 255: 1920 points
#     Angle:  0.074711 1/μm (valid: 1825/1920) ✓
#   Contour 256: 136 points
#     Angle:  0.236967 1/μm (valid: 136/136) ✓
#   Contour 257: 280 points
#     Angle:  0.141709 1/μm (valid: 274/280) ✓
#   Contour 258: 336 points
#     Angle:  0.083318 1/μm (valid: 316/336) ✓
#   Contour 259: 168 points
#     Angle:  0.221954 1/μm (valid: 165/168) ✓
#   Contour 260: 318 points
#     Angle:  0.188685 1/μm (valid: 310/318) ✓
#   Contour 261: 492 points
#     Angle:  0.100291 1/μm (valid: 439/492) ✓
#   Contour 262: 460 points
#     Angle:  0.091508 1/μm (valid: 435/460) ✓
#   Contour 263: 490 points
#     Angle:  0.185684 1/μm (valid: 468/490) ✓
#   Contour 264: 616 points
#     Angle:  0.068333 1/μm (valid: 594/616) ✓
#   Contour 265: 664 points
#     Angle:  0.086279 1/μm (valid: 639/664) ✓
#   Contour 266: 474 points
#     Angle:  0.103255 1/μm (valid: 450/474) ✓
#   Contour 267: 428 points
#     Angle:  0.110133 1/μm (valid: 350/428) ✓
#   Contour 268: 162 points
#     Angle:  0.341803 1/μm (valid: 151/162) ✓
#   Contour 269: 210 points
#     Angle:  0.202193 1/μm (valid: 202/210) ✓
#   Contour 270: 256 points
#     Angle:  0.123218 1/μm (valid: 246/256) ✓
#   Contour 271: 188 points
#     Angle:  0.197030 1/μm (valid: 179/188) ✓
#   Contour 272: 344 points
#     Angle:  0.131890 1/μm (valid: 336/344) ✓
#   Contour 273: 1052 points
#     Angle:  0.061616 1/μm (valid: 947/1052) ✓
#   Contour 274: 140 points
#     Angle:  0.346043 1/μm (valid: 138/140) ✓
#   Contour 275: 626 points
#     Angle:  0.171850 1/μm (valid: 601/626) ✓
#   Contour 276: 352 points
#     Angle:  0.128320 1/μm (valid: 342/352) ✓
#   Contour 277: 226 points
#     Angle:  0.210678 1/μm (valid: 222/226) ✓
#   Contour 278: 100 points
#     Angle:  0.296024 1/μm (valid: 100/100) ✓
#   Contour 279: 318 points
#     Angle:  0.209253 1/μm (valid: 307/318) ✓
#   Contour 280: 520 points
#     Angle:  0.084238 1/μm (valid: 492/520) ✓
#   Contour 281: 100 points
#     Angle:  0.415412 1/μm (valid: 100/100) ✓
#   Contour 282: 240 points
#     Angle:  0.145637 1/μm (valid: 231/240) ✓
#   Contour 283: 164 points
#     Angle:  0.194796 1/μm (valid: 162/164) ✓
#   Contour 284: 356 points
#     Angle:  0.113854 1/μm (valid: 339/356) ✓
#   Contour 285: 196 points
#     Angle:  0.271107 1/μm (valid: 194/196) ✓
#   Contour 286: 108 points
#     Angle:  0.292275 1/μm (valid: 108/108) ✓
#   Contour 287: 308 points
#     Angle:  0.178112 1/μm (valid: 297/308) ✓
#   Contour 288: 492 points
#     Angle:  0.118373 1/μm (valid: 467/492) ✓
#   Contour 289: 140 points
#     Angle:  0.210016 1/μm (valid: 140/140) ✓
#   Contour 290: 180 points
#     Angle:  0.189596 1/μm (valid: 177/180) ✓
#   Contour 291: 164 points
#     Angle:  0.170517 1/μm (valid: 162/164) ✓
#   Contour 292: 120 points
#     Angle:  0.239942 1/μm (valid: 119/120) ✓
#   Contour 293: 256 points
#     Angle:  0.155363 1/μm (valid: 250/256) ✓
#   Contour 294: 296 points
#     Angle:  0.233492 1/μm (valid: 290/296) ✓
#   Contour 295: 164 points
#     Angle:  0.221318 1/μm (valid: 156/164) ✓
#   Contour 296: 376 points
#     Angle:  0.080077 1/μm (valid: 358/376) ✓
#   Contour 297: 136 points
#     Angle:  0.210762 1/μm (valid: 136/136) ✓
#   Contour 298: 514 points
#     Angle:  0.132678 1/μm (valid: 497/514) ✓
#   Contour 299: 214 points
#     Angle:  0.277925 1/μm (valid: 211/214) ✓
#   Contour 300: 1066 points
#     Angle:  0.062906 1/μm (valid: 1026/1066) ✓
#   Contour 301: 128 points
#     Angle:  0.132488 1/μm (valid: 127/128) ✓
#   Contour 302: 100 points
#     Angle:  0.326018 1/μm (valid: 98/100) ✓
#   Contour 303: 196 points
#     Angle:  0.190574 1/μm (valid: 192/196) ✓
#   Contour 304: 196 points
#     Angle:  0.138778 1/μm (valid: 193/196) ✓
#   Contour 305: 230 points
#     Angle:  0.149136 1/μm (valid: 226/230) ✓
#   Contour 306: 148 points
#     Angle:  0.232405 1/μm (valid: 148/148) ✓
#   Contour 307: 966 points
#     Angle:  0.065566 1/μm (valid: 917/966) ✓
#   Contour 308: 148 points
#     Angle:  4.942967 1/μm (valid: 10/148) ✓
#   Contour 309: 252 points
#     Angle:  0.117584 1/μm (valid: 202/252) ✓
#   Contour 310: 180 points
#     Angle:  0.168254 1/μm (valid: 178/180) ✓
#   Contour 311: 190 points
#     Angle:  0.275704 1/μm (valid: 189/190) ✓
#   Contour 312: 496 points
#     Angle:  0.096868 1/μm (valid: 449/496) ✓
#   Contour 313: 116 points
#     Angle:  0.273338 1/μm (valid: 116/116) ✓
#   Contour 314: 244 points
#     Angle:  0.164670 1/μm (valid: 236/244) ✓
#   Contour 315: 160 points
#     Angle:  0.271233 1/μm (valid: 148/160) ✓
#   Contour 316: 314 points
#     Angle:  0.120075 1/μm (valid: 306/314) ✓
#   Contour 317: 786 points
#     Angle:  0.057416 1/μm (valid: 725/786) ✓
#   Contour 318: 218 points
#     Angle:  0.169911 1/μm (valid: 214/218) ✓
#   Contour 319: 540 points
#     Angle:  0.110276 1/μm (valid: 514/540) ✓
#   Contour 320: 240 points
#     Angle:  0.265415 1/μm (valid: 234/240) ✓
#   Contour 321: 164 points
#     Angle:  0.209271 1/μm (valid: 157/164) ✓
#   Contour 322: 140 points
#     Angle:  0.094979 1/μm (valid: 140/140) ✓
#   Contour 323: 106 points
#     Angle:  0.250124 1/μm (valid: 106/106) ✓
#   Contour 324: 112 points
#     Angle:  0.243871 1/μm (valid: 108/112) ✓
#   Contour 325: 400 points
#     Angle:  0.128594 1/μm (valid: 388/400) ✓
#   Contour 326: 108 points
#     Angle:  0.307883 1/μm (valid: 108/108) ✓
#   Contour 327: 246 points
#     Angle:  0.127389 1/μm (valid: 237/246) ✓
#   Contour 328: 216 points
#     Angle:  0.177312 1/μm (valid: 211/216) ✓
#   Contour 329: 134 points
#     Angle:  0.239856 1/μm (valid: 133/134) ✓
#   Contour 330: 296 points
#     Angle:  0.110668 1/μm (valid: 290/296) ✓
#   Contour 331: 102 points
#     Angle:  0.284259 1/μm (valid: 102/102) ✓
#   Contour 332: 172 points
#     Angle:  0.241242 1/μm (valid: 170/172) ✓
#   Contour 333: 200 points
#     Angle:  0.234989 1/μm (valid: 193/200) ✓
#   Contour 334: 742 points
#     Angle:  0.094187 1/μm (valid: 672/742) ✓
#   Contour 335: 288 points
#     Angle:  0.149135 1/μm (valid: 242/288) ✓
#   Contour 336: 232 points
#     Angle:  0.177152 1/μm (valid: 227/232) ✓
#   Contour 337: 418 points
#     Angle:  0.169407 1/μm (valid: 402/418) ✓
#   Contour 338: 128 points
#     Angle:  0.251305 1/μm (valid: 127/128) ✓
#   Contour 339: 530 points
#     Angle:  0.118061 1/μm (valid: 503/530) ✓
#   Contour 340: 134 points
#     Angle:  0.182532 1/μm (valid: 134/134) ✓
#   Contour 341: 442 points
#     Angle:  0.096268 1/μm (valid: 424/442) ✓
#   Contour 342: 656 points
#     Angle:  0.070414 1/μm (valid: 594/656) ✓
#   Contour 343: 164 points
#     Angle:  0.239374 1/μm (valid: 160/164) ✓
#   Contour 344: 160 points
#     Angle:  0.259579 1/μm (valid: 150/160) ✓
#   Contour 345: 146 points
#     Angle:  0.267517 1/μm (valid: 146/146) ✓
#   Contour 346: 344 points
#     Angle:  0.097718 1/μm (valid: 333/344) ✓
#   Contour 347: 360 points
#     Angle:  0.101455 1/μm (valid: 315/360) ✓
#   Contour 348: 116 points
#     Angle:  0.509640 1/μm (valid: 106/116) ✓
#   Contour 349: 164 points
#     Angle:  0.371143 1/μm (valid: 161/164) ✓
#   Contour 350: 136 points
#     Angle:  0.201604 1/μm (valid: 134/136) ✓
#   Contour 351: 116 points
#     Angle:  0.238279 1/μm (valid: 115/116) ✓
#   Contour 352: 216 points
#     Angle:  0.192047 1/μm (valid: 199/216) ✓
#   Contour 353: 104 points
#     Angle:  0.472493 1/μm (valid: 104/104) ✓
#   Contour 354: 112 points
#     Angle:  0.225032 1/μm (valid: 112/112) ✓
#   Contour 355: 148 points
#     Angle:  0.233524 1/μm (valid: 147/148) ✓
#   Contour 356: 224 points
#     Angle:  0.155721 1/μm (valid: 218/224) ✓
#   Contour 357: 856 points
#     Angle:  0.067821 1/μm (valid: 804/856) ✓
#   Contour 358: 148 points
#     Angle:  0.219334 1/μm (valid: 148/148) ✓
#   Contour 359: 472 points
#     Angle:  0.080306 1/μm (valid: 456/472) ✓
#   Contour 360: 154 points
#     Angle:  0.167826 1/μm (valid: 142/154) ✓
#   Contour 361: 576 points
#     Angle:  0.131858 1/μm (valid: 533/576) ✓
#   Contour 362: 384 points
#     Angle:  0.133616 1/μm (valid: 375/384) ✓
#   Contour 363: 288 points
#     Angle:  0.183077 1/μm (valid: 282/288) ✓
#   Contour 364: 112 points
#     Angle:  0.306019 1/μm (valid: 108/112) ✓
#   Contour 365: 216 points
#     Angle:  0.168056 1/μm (valid: 212/216) ✓
#   Contour 366: 408 points
#     Angle:  0.143778 1/μm (valid: 396/408) ✓
#   Contour 367: 140 points
#     Angle:  0.197656 1/μm (valid: 136/140) ✓
#   Contour 368: 240 points
#     Angle:  0.166039 1/μm (valid: 232/240) ✓
#   Contour 369: 450 points
#     Angle:  0.155201 1/μm (valid: 434/450) ✓
#   Contour 370: 220 points
#     Angle:  0.205859 1/μm (valid: 216/220) ✓
#   Contour 371: 498 points
#     Angle:  0.098817 1/μm (valid: 471/498) ✓
#   Contour 372: 1184 points
#     Angle:  0.054754 1/μm (valid: 976/1184) ✓
#   Contour 373: 104 points
#     Angle:  0.325637 1/μm (valid: 103/104) ✓
#   Contour 374: 1366 points
#     Angle:  0.091070 1/μm (valid: 1312/1366) ✓
#   Contour 375: 814 points
#     Angle:  0.072740 1/μm (valid: 760/814) ✓
#   Contour 376: 144 points
#     Angle:  0.134284 1/μm (valid: 141/144) ✓
#   Contour 377: 524 points
#     Angle:  0.088022 1/μm (valid: 495/524) ✓
#   Contour 378: 152 points
#     Angle:  0.255412 1/μm (valid: 149/152) ✓
#   Contour 379: 176 points
#     Angle:  0.240742 1/μm (valid: 174/176) ✓
#   Contour 380: 512 points
#     Angle:  0.130066 1/μm (valid: 469/512) ✓
#   Contour 381: 476 points
#     Angle:  0.084982 1/μm (valid: 457/476) ✓
#   Contour 382: 372 points
#     Angle:  0.121882 1/μm (valid: 356/372) ✓
#   Contour 383: 136 points
#     Angle:  0.203417 1/μm (valid: 136/136) ✓
#   Contour 384: 958 points
#     Angle:  0.058902 1/μm (valid: 862/958) ✓
#   Contour 385: 104 points
#     Angle:  0.361000 1/μm (valid: 104/104) ✓
#   Contour 386: 254 points
#     Angle:  0.178957 1/μm (valid: 247/254) ✓
#   Contour 387: 528 points
#     Angle:  0.125165 1/μm (valid: 512/528) ✓
#   Contour 388: 232 points
#     Angle:  0.132505 1/μm (valid: 225/232) ✓
#   Contour 389: 140 points
#     Angle:  0.271657 1/μm (valid: 135/140) ✓
#   Contour 390: 204 points
#     Angle:  0.259334 1/μm (valid: 191/204) ✓
#   Contour 391: 120 points
#     Angle:  0.313876 1/μm (valid: 119/120) ✓
#   Contour 392: 110 points
#     Angle:  0.318618 1/μm (valid: 110/110) ✓
#   Contour 393: 300 points
#     Angle:  0.147591 1/μm (valid: 281/300) ✓
#   Contour 394: 144 points
#     Angle:  0.277355 1/μm (valid: 144/144) ✓
#   Contour 395: 122 points
#     Angle:  0.353070 1/μm (valid: 122/122) ✓
#   Contour 396: 162 points
#     Angle:  0.372140 1/μm (valid: 161/162) ✓
#   Contour 397: 560 points
#     Angle:  0.103347 1/μm (valid: 532/560) ✓
#   Contour 398: 340 points
#     Angle:  0.195900 1/μm (valid: 332/340) ✓
#   Contour 399: 176 points
#     Angle:  0.221511 1/μm (valid: 174/176) ✓
#   Contour 400: 212 points
#     Angle:  0.159537 1/μm (valid: 207/212) ✓
#   Contour 401: 108 points
#     Angle:  0.224743 1/μm (valid: 108/108) ✓
#   Contour 402: 236 points
#     Angle:  0.128620 1/μm (valid: 231/236) ✓
#   Contour 403: 128 points
#     Angle:  0.234057 1/μm (valid: 123/128) ✓
#   Contour 404: 204 points
#     Angle:  0.162151 1/μm (valid: 200/204) ✓
#   Contour 405: 428 points
#     Angle:  0.165787 1/μm (valid: 415/428) ✓
#   Contour 406: 198 points
#     Angle:  0.215799 1/μm (valid: 187/198) ✓
#   Contour 407: 120 points
#     Angle:  0.351655 1/μm (valid: 118/120) ✓
#   Contour 408: 396 points
#     Angle:  0.127971 1/μm (valid: 384/396) ✓
#   Contour 409: 158 points
#     Angle:  0.198332 1/μm (valid: 156/158) ✓
#   Contour 410: 196 points
#     Angle:  0.187492 1/μm (valid: 192/196) ✓
#   Contour 411: 160 points
#     Angle:  0.302797 1/μm (valid: 156/160) ✓
#   Contour 412: 310 points
#     Angle:  0.255479 1/μm (valid: 301/310) ✓
#   Contour 413: 100 points
#     Angle:  0.332501 1/μm (valid: 100/100) ✓
#   Contour 414: 102 points
#     Angle:  0.249116 1/μm (valid: 102/102) ✓
#   Contour 415: 132 points
#     Angle:  0.285775 1/μm (valid: 131/132) ✓
#   Contour 416: 156 points
#     Angle:  0.190072 1/μm (valid: 146/156) ✓
#   Contour 417: 148 points
#     Angle:  0.174450 1/μm (valid: 148/148) ✓
#   Contour 418: 164 points
#     Angle:  0.225909 1/μm (valid: 162/164) ✓
#   Contour 419: 148 points
#     Angle:  0.202211 1/μm (valid: 147/148) ✓
#   Contour 420: 108 points
#     Angle:  0.291030 1/μm (valid: 108/108) ✓
#   Contour 421: 216 points
#     Angle:  0.178961 1/μm (valid: 212/216) ✓
#   Contour 422: 338 points
#     Angle:  0.116951 1/μm (valid: 319/338) ✓
#   Contour 423: 1814 points
#     Angle:  0.074830 1/μm (valid: 1677/1814) ✓
#   Contour 424: 108 points
#     Angle:  0.483020 1/μm (valid: 108/108) ✓
#   Contour 425: 136 points
#     Angle:  0.258677 1/μm (valid: 136/136) ✓
#   Contour 426: 204 points
#     Angle:  0.210112 1/μm (valid: 199/204) ✓
#   Contour 427: 552 points
#     Angle:  0.135305 1/μm (valid: 521/552) ✓
#   Contour 428: 100 points
#     Angle:  0.236505 1/μm (valid: 98/100) ✓
#   Contour 429: 332 points
#     Angle:  0.156645 1/μm (valid: 319/332) ✓
#   Contour 430: 312 points
#     Angle:  0.121026 1/μm (valid: 304/312) ✓
#   Contour 431: 188 points
#     Angle:  0.197840 1/μm (valid: 181/188) ✓
#   Contour 432: 192 points
#     Angle:  0.289350 1/μm (valid: 190/192) ✓
#   Contour 433: 136 points
#     Angle:  0.190841 1/μm (valid: 136/136) ✓
#   Contour 434: 312 points
#     Angle:  0.141193 1/μm (valid: 304/312) ✓
#   Contour 435: 152 points
#     Angle:  0.251509 1/μm (valid: 134/152) ✓
#   Contour 436: 108 points
#     Angle:  0.286294 1/μm (valid: 104/108) ✓
#   Contour 437: 562 points
#     Angle:  0.111402 1/μm (valid: 541/562) ✓
#   Contour 438: 174 points
#     Angle:  0.169863 1/μm (valid: 172/174) ✓
#   Contour 439: 162 points
#     Angle:  0.164501 1/μm (valid: 160/162) ✓
#   Contour 440: 254 points
#     Angle:  0.168441 1/μm (valid: 237/254) ✓
#   Contour 441: 108 points
#     Angle:  0.399052 1/μm (valid: 108/108) ✓
#   Contour 442: 100 points
#     Angle:  0.316915 1/μm (valid: 93/100) ✓
#   Contour 443: 120 points
#     Angle:  0.263293 1/μm (valid: 119/120) ✓
#   Contour 444: 424 points
#     Angle:  0.118608 1/μm (valid: 403/424) ✓
#   Contour 445: 262 points
#     Angle:  0.164542 1/μm (valid: 246/262) ✓
#   Contour 446: 148 points
#     Angle:  0.282842 1/μm (valid: 146/148) ✓
#   Contour 447: 120 points
#     Angle:  0.300973 1/μm (valid: 120/120) ✓
#   Contour 448: 218 points
#     Angle:  0.120811 1/μm (valid: 206/218) ✓
#   Contour 449: 116 points
#     Angle:  0.331623 1/μm (valid: 109/116) ✓
#   Contour 450: 412 points
#     Angle:  0.094402 1/μm (valid: 378/412) ✓
#   Contour 451: 152 points
#     Angle:  0.190108 1/μm (valid: 148/152) ✓
#   Contour 452: 132 points
#     Angle:  0.258464 1/μm (valid: 132/132) ✓
#   Contour 453: 284 points
#     Angle:  0.161605 1/μm (valid: 269/284) ✓
#   Contour 454: 484 points
#     Angle:  0.093745 1/μm (valid: 465/484) ✓
#   Contour 455: 370 points
#     Angle:  0.127141 1/μm (valid: 355/370) ✓
#   Contour 456: 500 points
#     Angle:  0.114227 1/μm (valid: 462/500) ✓
#   Contour 457: 740 points
#     Angle:  0.129693 1/μm (valid: 713/740) ✓
#   Contour 458: 556 points
#     Angle:  0.092655 1/μm (valid: 538/556) ✓
#   Contour 459: 140 points
#     Angle:  0.202837 1/μm (valid: 140/140) ✓
#   Contour 460: 406 points
#     Angle:  0.101508 1/μm (valid: 392/406) ✓
#   Contour 461: 184 points
#     Angle:  0.309244 1/μm (valid: 182/184) ✓
#   Contour 462: 104 points
#     Angle:  0.219935 1/μm (valid: 104/104) ✓
#   Contour 463: 284 points
#     Angle:  0.166944 1/μm (valid: 271/284) ✓
#   Contour 464: 648 points
#     Angle:  0.086274 1/μm (valid: 619/648) ✓
#   Contour 465: 204 points
#     Angle:  0.249413 1/μm (valid: 195/204) ✓
#   Contour 466: 1006 points
#     Angle:  0.088364 1/μm (valid: 967/1006) ✓
#   Contour 467: 168 points
#     Angle:  0.175466 1/μm (valid: 164/168) ✓
#   Contour 468: 218 points
#     Angle:  0.197706 1/μm (valid: 214/218) ✓
#   Contour 469: 100 points
#     Angle:  0.383296 1/μm (valid: 100/100) ✓
#   Contour 470: 224 points
#     Angle:  0.185333 1/μm (valid: 220/224) ✓
#   Contour 471: 216 points
#     Angle:  0.136606 1/μm (valid: 212/216) ✓
#   Contour 472: 120 points
#     Angle:  0.272445 1/μm (valid: 111/120) ✓
#   Contour 473: 120 points
#     Angle:  0.260311 1/μm (valid: 119/120) ✓
#   Contour 474: 112 points
#     Angle:  0.362378 1/μm (valid: 112/112) ✓
#   Contour 475: 144 points
#     Angle:  0.261389 1/μm (valid: 136/144) ✓
#   Contour 476: 454 points
#     Angle:  0.126545 1/μm (valid: 439/454) ✓
#   Contour 477: 180 points
#     Angle:  0.225779 1/μm (valid: 173/180) ✓
#   Contour 478: 112 points
#     Angle:  0.399410 1/μm (valid: 112/112) ✓
#   Contour 479: 588 points
#     Angle:  0.131088 1/μm (valid: 570/588) ✓
#   Contour 480: 608 points
#     Angle:  0.064290 1/μm (valid: 575/608) ✓
#   Contour 481: 200 points
#     Angle:  0.210935 1/μm (valid: 195/200) ✓
#   Contour 482: 380 points
#     Angle:  0.078102 1/μm (valid: 354/380) ✓
#   Contour 483: 190 points
#     Angle:  0.234812 1/μm (valid: 189/190) ✓
#   Contour 484: 256 points
#     Angle:  0.126489 1/μm (valid: 250/256) ✓
#   Contour 485: 188 points
#     Angle:  0.228616 1/μm (valid: 183/188) ✓
#   Contour 486: 168 points
#     Angle:  0.190894 1/μm (valid: 164/168) ✓
#   Contour 487: 132 points
#     Angle:  0.222013 1/μm (valid: 132/132) ✓
#   Contour 488: 116 points
#     Angle:  0.340700 1/μm (valid: 111/116) ✓
#   Contour 489: 148 points
#     Angle:  0.189157 1/μm (valid: 148/148) ✓
#   Contour 490: 308 points
#     Angle:  0.107366 1/μm (valid: 293/308) ✓
#   Contour 491: 324 points
#     Angle:  0.108509 1/μm (valid: 316/324) ✓
#   Contour 492: 304 points
#     Angle:  0.155950 1/μm (valid: 296/304) ✓
#   Contour 493: 220 points
#     Angle:  0.133819 1/μm (valid: 201/220) ✓
#   Contour 494: 124 points
#     Angle:  0.713260 1/μm (valid: 88/124) ✓
#   Contour 495: 570 points
#     Angle:  0.119955 1/μm (valid: 552/570) ✓
#   Contour 496: 328 points
#     Angle:  0.238647 1/μm (valid: 303/328) ✓
#   Contour 497: 256 points
#     Angle:  0.076620 1/μm (valid: 243/256) ✓
#   Contour 498: 168 points
#     Angle:  0.220977 1/μm (valid: 158/168) ✓
#   Contour 499: 516 points
#     Angle:  0.149604 1/μm (valid: 498/516) ✓
#   Contour 500: 1034 points
#     Angle:  0.069512 1/μm (valid: 995/1034) ✓
#   Contour 501: 342 points
#     Angle:  0.121902 1/μm (valid: 334/342) ✓
#   Contour 502: 280 points
#     Angle:  0.139656 1/μm (valid: 274/280) ✓
#   Contour 503: 100 points
#     Angle:  0.327225 1/μm (valid: 100/100) ✓
#   Contour 504: 252 points
#     Angle:  0.157009 1/μm (valid: 240/252) ✓
#   Contour 505: 428 points
#     Angle:  0.107177 1/μm (valid: 414/428) ✓
#   Contour 506: 2092 points
#     Angle:  0.088360 1/μm (valid: 1871/2092) ✓
#   Contour 507: 356 points
#     Angle:  0.101279 1/μm (valid: 316/356) ✓
#   Contour 508: 680 points
#     Angle:  0.085646 1/μm (valid: 641/680) ✓
#   Contour 509: 502 points
#     Angle:  0.111729 1/μm (valid: 486/502) ✓
#   Contour 510: 128 points
#     Angle:  4.653818 1/μm (valid: 10/128) ✓
#   Contour 511: 144 points
#     Angle:  4.906903 1/μm (valid: 10/144) ✓
#   Contour 512: 568 points
#     Angle:  0.108757 1/μm (valid: 541/568) ✓
#   Contour 513: 864 points
#     Angle:  0.080712 1/μm (valid: 814/864) ✓
#   Contour 514: 328 points
#     Angle:  0.262752 1/μm (valid: 215/328) ✓
#   Contour 515: 192 points
#     Angle:  0.155877 1/μm (valid: 190/192) ✓
#   Contour 516: 476 points
#     Angle:  0.226250 1/μm (valid: 356/476) ✓
#   Contour 517: 124 points
#     Angle:  0.130154 1/μm (valid: 124/124) ✓
#   Contour 518: 276 points
#     Angle:  5.863046 1/μm (valid: 10/276) ✓
#   Contour 519: 240 points
#     Angle:  0.108624 1/μm (valid: 236/240) ✓
#   Contour 520: 206 points
#     Angle:  0.151709 1/μm (valid: 202/206) ✓
#   Contour 521: 130 points
#     Angle:  0.193052 1/μm (valid: 129/130) ✓
#   Contour 522: 228 points
#     Angle:  0.173972 1/μm (valid: 213/228) ✓
#   Contour 523: 112 points
#     Angle:  0.141963 1/μm (valid: 112/112) ✓
#   Contour 524: 312 points
#     Angle:  0.092163 1/μm (valid: 294/312) ✓
# C:\Users\chenb\AppData\Local\Temp\ipykernel_1280\510663613.py:262: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# 2025-11-22 00:04:19,137 - INFO - Visualization saved to: C:\Users\chenb\Desktop\input_images\curvature_results\2108854-2-masson-4_02_Hematoxylin_Channel (3)_processed_curvature_analysis.png
# 2025-11-22 00:04:20,222 - INFO - CSV data saved to: C:\Users\chenb\Desktop\input_images\curvature_results\2108854-2-masson-4_02_Hematoxylin_Channel (3)_processed_curvature_data.csv
# 2025-11-22 00:04:20,229 - INFO - Summary report saved to: C:\Users\chenb\Desktop\input_images\curvature_results\summary_report.md
# 2025-11-22 00:04:20,230 - INFO - Batch processing finished.
# Processing completed. Results saved in: C:\Users\chenb\Desktop\input_images\curvature_results
